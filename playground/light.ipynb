# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
import tqdm

# %%
data = pd.read_csv("../dataset/light/light.csv")
single_data = data[['date', 'Power']]
single_data.to_csv("../dataset/light/light_single.csv", index=False)

# %%
# !python -u ../run.py \
            --is_training 1 \
            --root_path ../dataset/light \
            --data_path light.csv \
            --model_id light_288_96_single \
            --model LightTime \
            --task_name long_term_forecast \
            --data custom \
            --features S \
            --target Power \
            --seq_len 288 \
            --label_len 96 \
            --pred_len 96 \
            --enc_in 10 \
            --dec_in 10 \
            --c_out 1 \
            --d_model 128 \
            --n_heads 16 \
            --e_layers 2 \
            --patch_len 96 \
            --stride 1 \
            --dropout 0.1 \
            --train_epochs 40 \
            --patience 10 \
            --decomposition 1 \
            --loss mse \
            --use_gpu True \
            --inverse \
            --itr 1 --batch_size 256 --learning_rate 0.001
# Out:
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           light_288_96_single Model:              LightTime
#
# Data Loader
#   Data:               custom              Root Path:          ../dataset/light
#   Data Path:          light.csv           Features:           S
#   Target:             Power               Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            288                 Label Len:          96
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            1
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             10                  Dec In:             10
#   C Out:              1                   d model:            128
#   n heads:            16                  e layers:           2
#   d layers:           1                   d FF:               2048
# ...
