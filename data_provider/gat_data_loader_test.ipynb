# %%
import gat_data_loader
from gat_data_loader import *
import tqdm as notebook_tqdm

# %%
config = DataConfig()
config.data_dir = "/mnt/EDisk/MyProject/WindSeedForecasting/Time-Series-Library/dataset/spatial_wind"  # 你的数据目录
config.edge_file = "/mnt/EDisk/MyProject/WindSeedForecasting/Time-Series-Library/dataset/spatial_wind/edges.csv"   # 边文件路径

# %%
 # 步骤1: 生成边文件（如果不存在）
config.correlation_threshold = 0.95  # 相关性阈值
if not os.path.exists(config.edge_file):
    print("\nGenerating graph edges...")
    edge_generator = AdvancedEdgeGenerator(config.data_dir, target_col=config.target_col)
    
    edges = edge_generator.generate_edges(
        methods=['correlation'],
        output_file=config.edge_file,
        threshold=config.correlation_threshold,
        top_k=config.top_k_edges,
        visualization=True
    )
else:
    print(f"Using existing edge file: {config.edge_file}")
# Out:
# Using existing edge file: /mnt/EDisk/MyProject/WindSeedForecasting/Time-Series-Library/dataset/spatial_wind/edges.csv

# %%
config.batch_size = 16
config.seq_len = 432
config.pred_len = 96
config.target_col = 'Wspd'
config.scaler_type = 'standard'
config.shuffle = True
config.root_path = "../dataset/spatial_wind"
print("\nCreating dataloader...")
try:
    train_loader, train_dataset = create_dataloader(
       config,
       'train'
    )
    
    # 更新配置
    config.n_nodes = len(train_dataset.processed_data)
    config.enc_in = list(train_dataset.processed_data.values())[0]['features'].shape[1]
    
    print(f"Training dataset: {len(train_dataset)} samples")
    print(f"Number of nodes: {config.n_nodes}")
    print(f"Features per node: {config.enc_in}")
    
    # 步骤3: 测试数据加载
    print("\nStep 3: Testing data loading...")
    for i, batch in enumerate(train_loader):
        print(f"Batch {i}: x={batch.x.shape}, y={batch.y.shape}, edges={batch.edge_index.shape[1]}")
        
        if i >= 2:  # 只测试前3个批次
            break
except Exception as e:
    print(f"Error creating dataloader: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Creating dataloader...
# Loading data files for train set...
# Found 135 data files
# Loaded dated_Turb1: 35280 records
# Loaded dated_Turb10: 35280 records
# Loaded dated_Turb100: 35280 records
# Loaded dated_Turb101: 35280 records
# Loaded dated_Turb102: 35280 records
# Loaded dated_Turb103: 35280 records
# Loaded dated_Turb104: 35280 records
# Loaded dated_Turb105: 35280 records
# Loaded dated_Turb106: 35280 records
# Loaded dated_Turb107: 35280 records
# Loaded dated_Turb108: 35280 records
# Loaded dated_Turb109: 35280 records
# Loaded dated_Turb11: 35280 records
# Loaded dated_Turb110: 35280 records
# Loaded dated_Turb111: 35280 records
# Loaded dated_Turb112: 35280 records
# Loaded dated_Turb113: 35280 records
# Loaded dated_Turb114: 35280 records
# Loaded dated_Turb115: 35280 records
# Loaded dated_Turb116: 35280 records
# Loaded dated_Turb117: 35280 records
# Loaded dated_Turb118: 35280 records
# Loaded dated_Turb119: 35280 records
# Loaded dated_Turb12: 35280 records
# Loaded dated_Turb120: 35280 records
# Loaded dated_Turb121: 35280 records
# Loaded dated_Turb122: 35280 records
# Loaded dated_Turb123: 35280 records
# Loaded dated_Turb124: 35280 records
# Loaded dated_Turb125: 35280 records
# Loaded dated_Turb126: 35280 records
# Loaded dated_Turb127: 35280 records
# Loaded dated_Turb128: 35280 records
# Loaded dated_Turb129: 35280 records
# Loaded dated_Turb13: 35280 records
# Loaded dated_Turb130: 35280 records
# Loaded dated_Turb131: 35280 records
# Loaded dated_Turb132: 35280 records
# Loaded dated_Turb133: 35280 records
# Loaded dated_Turb134: 35280 records
# Loaded dated_Turb14: 35280 records
# Loaded dated_Turb15: 35280 records
# Loaded dated_Turb16: 35280 records
# Loaded dated_Turb17: 35280 records
# Loaded dated_Turb18: 35280 records
# Loaded dated_Turb19: 35280 records
# Loaded dated_Turb2: 35280 records
# Loaded dated_Turb20: 35280 records
# Loaded dated_Turb21: 35280 records
# Loaded dated_Turb22: 35280 records
# Loaded dated_Turb23: 35280 records
# Loaded dated_Turb24: 35280 records
# Loaded dated_Turb25: 35280 records
# Loaded dated_Turb26: 35280 records
# Loaded dated_Turb27: 35280 records
# Loaded dated_Turb28: 35280 records
# Loaded dated_Turb29: 35280 records
# Loaded dated_Turb3: 35280 records
# Loaded dated_Turb30: 35280 records
# Loaded dated_Turb31: 35280 records
# Loaded dated_Turb32: 35280 records
# Loaded dated_Turb33: 35280 records
# Loaded dated_Turb34: 35280 records
# Loaded dated_Turb35: 35280 records
# Loaded dated_Turb36: 35280 records
# Loaded dated_Turb37: 35280 records
# Loaded dated_Turb38: 35280 records
# Loaded dated_Turb39: 35280 records
# Loaded dated_Turb4: 35280 records
# Loaded dated_Turb40: 35280 records
# Loaded dated_Turb41: 35280 records
# Loaded dated_Turb42: 35280 records
# Loaded dated_Turb43: 35280 records
# Loaded dated_Turb44: 35280 records
# Loaded dated_Turb45: 35280 records
# Loaded dated_Turb46: 35280 records
# Loaded dated_Turb47: 35280 records
# Loaded dated_Turb48: 35280 records
# Loaded dated_Turb49: 35280 records
# Loaded dated_Turb5: 35280 records
# Loaded dated_Turb50: 35280 records
# Loaded dated_Turb51: 35280 records
# Loaded dated_Turb52: 35280 records
# Loaded dated_Turb53: 35280 records
# Loaded dated_Turb54: 35280 records
# Loaded dated_Turb55: 35280 records
# Loaded dated_Turb56: 35280 records
# Loaded dated_Turb57: 35280 records
# Loaded dated_Turb58: 35280 records
# Loaded dated_Turb59: 35280 records
# Loaded dated_Turb6: 35280 records
# Loaded dated_Turb60: 35280 records
# Loaded dated_Turb61: 35280 records
# Loaded dated_Turb62: 35280 records
# Loaded dated_Turb63: 35280 records
# Loaded dated_Turb64: 35280 records
# Loaded dated_Turb65: 35280 records
# Loaded dated_Turb66: 35280 records
# Loaded dated_Turb67: 35280 records
# Loaded dated_Turb68: 35280 records
# Loaded dated_Turb69: 35280 records
# Loaded dated_Turb7: 35280 records
# Loaded dated_Turb70: 35280 records
# Loaded dated_Turb71: 35280 records
# Loaded dated_Turb72: 35280 records
# Loaded dated_Turb73: 35280 records
# Loaded dated_Turb74: 35280 records
# Loaded dated_Turb75: 35280 records
# Loaded dated_Turb76: 35280 records
# Loaded dated_Turb77: 35280 records
# Loaded dated_Turb78: 35280 records
# Loaded dated_Turb79: 35280 records
# Loaded dated_Turb8: 35280 records
# Loaded dated_Turb80: 35280 records
# Loaded dated_Turb81: 35280 records
# Loaded dated_Turb82: 35280 records
# Loaded dated_Turb83: 35280 records
# Loaded dated_Turb84: 35280 records
# Loaded dated_Turb85: 35280 records
# Loaded dated_Turb86: 35280 records
# Loaded dated_Turb87: 35280 records
# Loaded dated_Turb88: 35280 records
# Loaded dated_Turb89: 35280 records
# Loaded dated_Turb9: 35280 records
# Loaded dated_Turb90: 35280 records
# Loaded dated_Turb91: 35280 records
# Loaded dated_Turb92: 35280 records
# Loaded dated_Turb93: 35280 records
# Loaded dated_Turb94: 35280 records
# Loaded dated_Turb95: 35280 records
# Loaded dated_Turb96: 35280 records
# Loaded dated_Turb97: 35280 records
# Loaded dated_Turb98: 35280 records
# Loaded dated_Turb99: 35280 records
# Loaded edges: 4482 records
# Preprocessing data...
# Common time range: 2024-01-01 00:00:00 to 2024-09-01 23:50:00
# Processed dated_Turb1: (35280, 10)
# Processed dated_Turb10: (35280, 10)
# Processed dated_Turb100: (35280, 10)
# Processed dated_Turb101: (35280, 10)
# Processed dated_Turb102: (35280, 10)
# Processed dated_Turb103: (35280, 10)
# Processed dated_Turb104: (35280, 10)
# Processed dated_Turb105: (35280, 10)
# Processed dated_Turb106: (35280, 10)
# Processed dated_Turb107: (35280, 10)
# Processed dated_Turb108: (35280, 10)
# Processed dated_Turb109: (35280, 10)
# Processed dated_Turb11: (35280, 10)
# Processed dated_Turb110: (35280, 10)
# Processed dated_Turb111: (35280, 10)
# Processed dated_Turb112: (35280, 10)
# Processed dated_Turb113: (35280, 10)
# Processed dated_Turb114: (35280, 10)
# Processed dated_Turb115: (35280, 10)
# Processed dated_Turb116: (35280, 10)
# Processed dated_Turb117: (35280, 10)
# Processed dated_Turb118: (35280, 10)
# Processed dated_Turb119: (35280, 10)
# Processed dated_Turb12: (35280, 10)
# Processed dated_Turb120: (35280, 10)
# Processed dated_Turb121: (35280, 10)
# Processed dated_Turb122: (35280, 10)
# Processed dated_Turb123: (35280, 10)
# Processed dated_Turb124: (35280, 10)
# Processed dated_Turb125: (35280, 10)
# Processed dated_Turb126: (35280, 10)
# Processed dated_Turb127: (35280, 10)
# Processed dated_Turb128: (35280, 10)
# Processed dated_Turb129: (35280, 10)
# Processed dated_Turb13: (35280, 10)
# Processed dated_Turb130: (35280, 10)
# Processed dated_Turb131: (35280, 10)
# Processed dated_Turb132: (35280, 10)
# Processed dated_Turb133: (35280, 10)
# Processed dated_Turb134: (35280, 10)
# Processed dated_Turb14: (35280, 10)
# Processed dated_Turb15: (35280, 10)
# Processed dated_Turb16: (35280, 10)
# Processed dated_Turb17: (35280, 10)
# Processed dated_Turb18: (35280, 10)
# Processed dated_Turb19: (35280, 10)
# Processed dated_Turb2: (35280, 10)
# Processed dated_Turb20: (35280, 10)
# Processed dated_Turb21: (35280, 10)
# Processed dated_Turb22: (35280, 10)
# Processed dated_Turb23: (35280, 10)
# Processed dated_Turb24: (35280, 10)
# Processed dated_Turb25: (35280, 10)
# Processed dated_Turb26: (35280, 10)
# Processed dated_Turb27: (35280, 10)
# Processed dated_Turb28: (35280, 10)
# Processed dated_Turb29: (35280, 10)
# Processed dated_Turb3: (35280, 10)
# Processed dated_Turb30: (35280, 10)
# Processed dated_Turb31: (35280, 10)
# Processed dated_Turb32: (35280, 10)
# Processed dated_Turb33: (35280, 10)
# Processed dated_Turb34: (35280, 10)
# Processed dated_Turb35: (35280, 10)
# Processed dated_Turb36: (35280, 10)
# Processed dated_Turb37: (35280, 10)
# Processed dated_Turb38: (35280, 10)
# Processed dated_Turb39: (35280, 10)
# Processed dated_Turb4: (35280, 10)
# Processed dated_Turb40: (35280, 10)
# Processed dated_Turb41: (35280, 10)
# Processed dated_Turb42: (35280, 10)
# Processed dated_Turb43: (35280, 10)
# Processed dated_Turb44: (35280, 10)
# Processed dated_Turb45: (35280, 10)
# Processed dated_Turb46: (35280, 10)
# Processed dated_Turb47: (35280, 10)
# Processed dated_Turb48: (35280, 10)
# Processed dated_Turb49: (35280, 10)
# Processed dated_Turb5: (35280, 10)
# Processed dated_Turb50: (35280, 10)
# Processed dated_Turb51: (35280, 10)
# Processed dated_Turb52: (35280, 10)
# Processed dated_Turb53: (35280, 10)
# Processed dated_Turb54: (35280, 10)
# Processed dated_Turb55: (35280, 10)
# Processed dated_Turb56: (35280, 10)
# Processed dated_Turb57: (35280, 10)
# Processed dated_Turb58: (35280, 10)
# Processed dated_Turb59: (35280, 10)
# Warning: NaN values found in dated_Turb6, filling with forward fill
# Processed dated_Turb6: (35280, 10)
# Processed dated_Turb60: (35280, 10)
# Processed dated_Turb61: (35280, 10)
# Processed dated_Turb62: (35280, 10)
# Processed dated_Turb63: (35280, 10)
# Processed dated_Turb64: (35280, 10)
# Processed dated_Turb65: (35280, 10)
# Processed dated_Turb66: (35280, 10)
# Processed dated_Turb67: (35280, 10)
# Processed dated_Turb68: (35280, 10)
# Processed dated_Turb69: (35280, 10)
# Processed dated_Turb7: (35280, 10)
# Processed dated_Turb70: (35280, 10)
# Processed dated_Turb71: (35280, 10)
# Processed dated_Turb72: (35280, 10)
# Processed dated_Turb73: (35280, 10)
# Processed dated_Turb74: (35280, 10)
# Processed dated_Turb75: (35280, 10)
# Processed dated_Turb76: (35280, 10)
# Processed dated_Turb77: (35280, 10)
# Processed dated_Turb78: (35280, 10)
# Processed dated_Turb79: (35280, 10)
# Processed dated_Turb8: (35280, 10)
# Processed dated_Turb80: (35280, 10)
# Processed dated_Turb81: (35280, 10)
# Processed dated_Turb82: (35280, 10)
# Processed dated_Turb83: (35280, 10)
# Processed dated_Turb84: (35280, 10)
# Processed dated_Turb85: (35280, 10)
# Processed dated_Turb86: (35280, 10)
# Processed dated_Turb87: (35280, 10)
# Processed dated_Turb88: (35280, 10)
# Processed dated_Turb89: (35280, 10)
# Processed dated_Turb9: (35280, 10)
# Processed dated_Turb90: (35280, 10)
# Processed dated_Turb91: (35280, 10)
# Processed dated_Turb92: (35280, 10)
# Processed dated_Turb93: (35280, 10)
# Processed dated_Turb94: (35280, 10)
# Processed dated_Turb95: (35280, 10)
# Processed dated_Turb96: (35280, 10)
# Processed dated_Turb97: (35280, 10)
# Processed dated_Turb98: (35280, 10)
# Processed dated_Turb99: (35280, 10)
# Error preprocessing edges: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# Generating/loading graph edges...
# Loaded 4482 edges from /mnt/EDisk/MyProject/WindSeedForecasting/Time-Series-Library/dataset/spatial_wind/edges.csv
# Creating samples for train set...
# Created 24326 train samples (seq_len=432, pred_len=96)
# Split info - Total: 34752, Train: 24326, Val: 6950, Test: 3476
# TRAIN dataset initialized: 24326 samples, 134 nodes
# train dataset size: 24326
# Training dataset: 24326 samples
# Number of nodes: 134
# Features per node: 10
#
# Step 3: Testing data loading...
# Batch 0: x=torch.Size([16, 134, 432, 10]), y=torch.Size([16, 134, 96]), edges=71712
# Batch 1: x=torch.Size([16, 134, 432, 10]), y=torch.Size([16, 134, 96]), edges=71712
# Batch 2: x=torch.Size([16, 134, 432, 10]), y=torch.Size([16, 134, 96]), edges=71712
